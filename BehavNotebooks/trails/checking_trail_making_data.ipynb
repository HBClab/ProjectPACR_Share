# %%
import pandas as pd
import numpy as np
import time

# %%
trails = pd.read_csv('PACR_DATA_2018-01-08_1413.csv')

# %%
# take a look at the damage
trails
# Out:
#      lab_id  bike_id        tm_a    tm_ae        tm_b    tm_be          at  \
# 0         1       15         NaN      NaN         NaN      NaN         NaN
# 1        44        8       23.02        0       68.01        0  23 seconds
# 2        45       41          28        0          39        0         NaN
# 3        58       25  28 seconds        0  41 seconds        0       21.61
# 4        68       12          42        0          62        0  26 seconds
# 5        87        7  29 seconds        0  60 seconds        0  27 seconds
# 6        92        9  41 seconds        1  82 seconds        0       39.51
# 7       157       51  28 seconds        0  54 seconds        0       23.93
# 8       182       31  37 seconds        0  75 seconds        0          36
# 9       200       13  43 seconds        0  58 seconds        0        40.3
# 10      201        6  29 seconds        0  48 seconds        0       26.03
# 11      207       11          30        1          59        0          24
# 12      217       52  59 seconds        1  72 seconds        2  47 seconds
# 13      234       55  44 seconds        0  92 seconds        0       34.63
# 14      311       10       31.63        0       51.25        0       25.56
# 15      336        4         NaN      NaN         NaN      NaN         NaN
# 16      338        3          25        1        1:16        2         NaN
# 17      496       32         NaN      NaN         NaN      NaN         NaN
# 18      497       26         NaN      NaN         NaN      NaN         NaN
# 19      498      102     22.69 s        0     48.49 s        0       21.22
# 20      499       34         NaN      NaN         NaN      NaN         NaN
# 21      500       24  38 seconds        0  68 seconds        0       33.08
# 22      501       38         NaN      NaN         NaN      NaN         NaN
# 23      503       39          25        0          78        0  27 seconds
# 24      505       43    19.03 s         0       54.65        0  26 seconds
# 25      506       42         NaN      NaN         NaN      NaN         NaN
# 26      507       46         NaN      NaN         NaN      NaN         NaN
# 27      508       44       40.78        0       61.04        0         NaN
# 28      519       56  26 seconds  0 error  54 seconds  2 error         NaN
# 29      522       45        29.6        0        39.2        0       18.67
# ..      ...      ...         ...      ...         ...      ...         ...
# 77      634      161        19.3        1       55.81        1       21.98
# 78      639      163         NaN      NaN         NaN      NaN         NaN
# 79      644        5       30.67        0       42.07        0       24.58
# 80      649      166       20.85        0       50.99        1        20.9
# 81      651      170         NaN      NaN         NaN      NaN         NaN
# 82      654      173         NaN      NaN         NaN      NaN         NaN
# 83      655      178       25.37        0       92.96        1       25.93
# 84      656      172       29.44        0       58.82        0         NaN
# 85      658      185       40.82        0       89.32        0         NaN
# 86      659      164        24.8        0      102.14        2       19.87
# 87      660      169         NaN      NaN         NaN      NaN         NaN
# 88      662      171         NaN      NaN         NaN      NaN         NaN
# 89      663      184         NaN      NaN         NaN      NaN         NaN
# 90      665      180         NaN      NaN         NaN      NaN         NaN
# 91      666      182       31.19        0      128.49       18       33.21
# 92      667      186       37.83        0       92.08        0        3.25
# 93      668      181         NaN      NaN         NaN      NaN         NaN
# 94      669      174       26.75        0        64.5        0       26.74
# 95      670      190       14.72        0        41.3        0       15.08
# 96      671      176       25.82        0          74        1       22.82
# 97      674      197       35.29        0      116.34        1       29.24
# 98      675      191       41.23        0      119.99        0       38.42
# 99      676      199       25.21        0       58.85        2       22.32
# 100     677      195       35.12        0       58.03        0          21
# 101     678      202       50.45        0       58.44        0         NaN
# 102     682      203         NaN      NaN         NaN      NaN         NaN
# 103     684      204       48.46        0       41.65        0       21.17
# 104     687      206       29.46        0       73.68        2       24.38
# 105     695      208         NaN      NaN         NaN      NaN         NaN
# 106     713      209        34.2        0       72.26        1       34.32
#
#          pae          bt       be
# 0        NaN         NaN      NaN
# 1    0 error  44 seconds  0 error
# 2        NaN         NaN      NaN
# 3          0       48.51        0
# 4    0 error  61 seconds  0 error
# 5          0  63 seconds        0
# 6          1       72.12        0
# 7          0       45.08        4
# 8          0          63        0
# 9          1       64.93        0
# 10         0       46.67        0
# 11         0          43        0
# 12   0 error  79 seconds  0 error
# 13         0       58.39        0
# 14         0       43.03        0
# 15       NaN         NaN      NaN
# 16       NaN         NaN      NaN
# 17       NaN         NaN      NaN
# 18       NaN         NaN      NaN
# 19         0        70.6        0
# 20       NaN         NaN      NaN
# 21         0       63.14        0
# 22       NaN         NaN      NaN
# 23   1 error  64 seconds  0 error
# 24         3  63 seconds        0
# 25       NaN         NaN      NaN
# 26       NaN         NaN      NaN
# 27       NaN         NaN      NaN
# 28       NaN         NaN      NaN
# 29         0       41.71        0
# ..       ...         ...      ...
# 77         0       40.46        0
# 78       NaN         NaN      NaN
# 79         0       37.26        0
# 80         0       41.49        1
# 81       NaN         NaN      NaN
# 82       NaN         NaN      NaN
# 83         0       77.08        1
# 84       NaN         NaN      NaN
# 85       NaN         NaN      NaN
# 86         0       66.38        1
# 87       NaN         NaN      NaN
# 88       NaN         NaN      NaN
# 89       NaN         NaN      NaN
# 90       NaN         NaN      NaN
# 91         0       59.27        0
# 92         0        90.3        0
# 93       NaN         NaN      NaN
# 94         0       84.37        0
# 95         0       31.65        0
# 96         0       69.89        0
# 97         2       62.73        2
# 98         3       74.88        0
# 99         0       35.71        0
# 100        0       46.07        1
# 101      NaN         NaN      NaN
# 102      NaN         NaN      NaN
# 103        0       38.75        0
# 104        0       81.69        0
# 105      NaN         NaN      NaN
# 106        0       74.59        1
#
# [107 rows x 10 columns]

# %% [markdown]
# ## Several items we need to consider:
# - How should the data be represented? earlier it was reported as integers, but later decimals were introduced.
#     - just going to go with float representation for now to keep the detailed data detailed
# - Removal of strings (e.g. the 'seconds' and 'errors' strings)
#     - going to make a function to format strings to floats
# - Transfer the 1:00 representations of time to seconds
#     - going to make a function to format time to seconds
# - How should NANs and 0s be represented
#     - As they are since they have differential meanings, (e.g. NANs mean did not complete, whereas zeros mean there were not any errors) (hopefully there are no cases where it took 0 seconds to complete the task)

# %%
# transfers 1:20(.22) to 80(.22)
def minutes2seconds(m):
    # if there are milliseconds
    if m.find('.') > 0:
        # treat ms separately and add them in at the end
        tim, ms = m.split('.',1)
    else:
        # ignore ms, which will treated as 0
        tim = m
        ms = ''
    if ms != '':
        # convert milliseconds to their appropiate format
        ms = float(ms) / 100
    else:
        # treat milliseconds as zero (if it doesn't exist)
        ms = 0
    # make a time object to parse minutes and seconds
    tt=time.strptime(tim,"%M:%S")
    # add all the components up.
    return tt.tm_min * 60 + tt.tm_sec + ms

def format_series(s):
    # if the datatype is a string and its a time (e.g. 1:20)
    if type(s) is str and s.find(':') > 0:
        out = float(minutes2seconds(s))
    # if the datatype is just a string (e.g. '54 seconds')
    elif type(s) is str:
        out = float(s.rstrip('[secondserrors ]'))
    # else the datatype is already a number
    else:
        out = float(s)
    return out

# main function
def remove_str(series):
    return series.map(format_series)

# %%
# apply the function to all columns
trails_fmt = trails.apply(remove_str)

# %%
# lets see how much better the data look
trails_fmt
# Out:
#      lab_id  bike_id   tm_a  tm_ae    tm_b  tm_be     at  pae     bt   be
# 0       1.0     15.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 1      44.0      8.0  23.02    0.0   68.01    0.0  23.00  0.0  44.00  0.0
# 2      45.0     41.0  28.00    0.0   39.00    0.0    NaN  NaN    NaN  NaN
# 3      58.0     25.0  28.00    0.0   41.00    0.0  21.61  0.0  48.51  0.0
# 4      68.0     12.0  42.00    0.0   62.00    0.0  26.00  0.0  61.00  0.0
# 5      87.0      7.0  29.00    0.0   60.00    0.0  27.00  0.0  63.00  0.0
# 6      92.0      9.0  41.00    1.0   82.00    0.0  39.51  1.0  72.12  0.0
# 7     157.0     51.0  28.00    0.0   54.00    0.0  23.93  0.0  45.08  4.0
# 8     182.0     31.0  37.00    0.0   75.00    0.0  36.00  0.0  63.00  0.0
# 9     200.0     13.0  43.00    0.0   58.00    0.0  40.30  1.0  64.93  0.0
# 10    201.0      6.0  29.00    0.0   48.00    0.0  26.03  0.0  46.67  0.0
# 11    207.0     11.0  30.00    1.0   59.00    0.0  24.00  0.0  43.00  0.0
# 12    217.0     52.0  59.00    1.0   72.00    2.0  47.00  0.0  79.00  0.0
# 13    234.0     55.0  44.00    0.0   92.00    0.0  34.63  0.0  58.39  0.0
# 14    311.0     10.0  31.63    0.0   51.25    0.0  25.56  0.0  43.03  0.0
# 15    336.0      4.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 16    338.0      3.0  25.00    1.0   76.00    2.0    NaN  NaN    NaN  NaN
# 17    496.0     32.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 18    497.0     26.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 19    498.0    102.0  22.69    0.0   48.49    0.0  21.22  0.0  70.60  0.0
# 20    499.0     34.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 21    500.0     24.0  38.00    0.0   68.00    0.0  33.08  0.0  63.14  0.0
# 22    501.0     38.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 23    503.0     39.0  25.00    0.0   78.00    0.0  27.00  1.0  64.00  0.0
# 24    505.0     43.0  19.03    0.0   54.65    0.0  26.00  3.0  63.00  0.0
# 25    506.0     42.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 26    507.0     46.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 27    508.0     44.0  40.78    0.0   61.04    0.0    NaN  NaN    NaN  NaN
# 28    519.0     56.0  26.00    0.0   54.00    2.0    NaN  NaN    NaN  NaN
# 29    522.0     45.0  29.60    0.0   39.20    0.0  18.67  0.0  41.71  0.0
# ..      ...      ...    ...    ...     ...    ...    ...  ...    ...  ...
# 77    634.0    161.0  19.30    1.0   55.81    1.0  21.98  0.0  40.46  0.0
# 78    639.0    163.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 79    644.0      5.0  30.67    0.0   42.07    0.0  24.58  0.0  37.26  0.0
# 80    649.0    166.0  20.85    0.0   50.99    1.0  20.90  0.0  41.49  1.0
# 81    651.0    170.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 82    654.0    173.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 83    655.0    178.0  25.37    0.0   92.96    1.0  25.93  0.0  77.08  1.0
# 84    656.0    172.0  29.44    0.0   58.82    0.0    NaN  NaN    NaN  NaN
# 85    658.0    185.0  40.82    0.0   89.32    0.0    NaN  NaN    NaN  NaN
# 86    659.0    164.0  24.80    0.0  102.14    2.0  19.87  0.0  66.38  1.0
# 87    660.0    169.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 88    662.0    171.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 89    663.0    184.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 90    665.0    180.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 91    666.0    182.0  31.19    0.0  128.49   18.0  33.21  0.0  59.27  0.0
# 92    667.0    186.0  37.83    0.0   92.08    0.0   3.25  0.0  90.30  0.0
# 93    668.0    181.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 94    669.0    174.0  26.75    0.0   64.50    0.0  26.74  0.0  84.37  0.0
# 95    670.0    190.0  14.72    0.0   41.30    0.0  15.08  0.0  31.65  0.0
# 96    671.0    176.0  25.82    0.0   74.00    1.0  22.82  0.0  69.89  0.0
# 97    674.0    197.0  35.29    0.0  116.34    1.0  29.24  2.0  62.73  2.0
# 98    675.0    191.0  41.23    0.0  119.99    0.0  38.42  3.0  74.88  0.0
# 99    676.0    199.0  25.21    0.0   58.85    2.0  22.32  0.0  35.71  0.0
# 100   677.0    195.0  35.12    0.0   58.03    0.0  21.00  0.0  46.07  1.0
# 101   678.0    202.0  50.45    0.0   58.44    0.0    NaN  NaN    NaN  NaN
# 102   682.0    203.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 103   684.0    204.0  48.46    0.0   41.65    0.0  21.17  0.0  38.75  0.0
# 104   687.0    206.0  29.46    0.0   73.68    2.0  24.38  0.0  81.69  0.0
# 105   695.0    208.0    NaN    NaN     NaN    NaN    NaN  NaN    NaN  NaN
# 106   713.0    209.0  34.20    0.0   72.26    1.0  34.32  0.0  74.59  1.0
#
# [107 rows x 10 columns]

# %% [markdown]
# ## Give Informative Column Names
# To tidy up some more, we will change the column names to more informative/accurate names

# %%
col_names = {'lab_id': 'lab_id', 
             'bike_id': 'pacr_id', 
             'tm_a': 'pre_time_a', 
             'tm_ae': 'pre_err_a', 
             'tm_b': 'pre_time_b', 
             'tm_be': 'pre_err_b', 
             'at': 'post_time_a', 
             'pae': 'post_err_a', 
             'bt': 'post_time_b', 
             'be': 'post_err_b'}

trails_fmt.rename(columns=col_names, inplace=True)

# %% [markdown]
# ## Overzealous Floats
# I was a bit overzealous with converting to floats, so I should change lab_id, pacr_id, and the err columns to integers
#
# EDIT: [pandas represents NaNs as floats, can't change them](https://pandas.pydata.org/pandas-docs/stable/gotchas.html#nan-integer-na-values-and-na-type-promotions).
#
# So I will only be changing lab_id and pacr_id as integers

# %%
trails_fmt[['lab_id', 'pacr_id']] = trails_fmt[['lab_id','pacr_id']].astype(int)

# %%
# lets see the tidier dataset
trails_fmt
# Out:
#      lab_id  pacr_id  pre_time_a  pre_err_a  pre_time_b  pre_err_b  \
# 0         1       15         NaN        NaN         NaN        NaN
# 1        44        8       23.02        0.0       68.01        0.0
# 2        45       41       28.00        0.0       39.00        0.0
# 3        58       25       28.00        0.0       41.00        0.0
# 4        68       12       42.00        0.0       62.00        0.0
# 5        87        7       29.00        0.0       60.00        0.0
# 6        92        9       41.00        1.0       82.00        0.0
# 7       157       51       28.00        0.0       54.00        0.0
# 8       182       31       37.00        0.0       75.00        0.0
# 9       200       13       43.00        0.0       58.00        0.0
# 10      201        6       29.00        0.0       48.00        0.0
# 11      207       11       30.00        1.0       59.00        0.0
# 12      217       52       59.00        1.0       72.00        2.0
# 13      234       55       44.00        0.0       92.00        0.0
# 14      311       10       31.63        0.0       51.25        0.0
# 15      336        4         NaN        NaN         NaN        NaN
# 16      338        3       25.00        1.0       76.00        2.0
# 17      496       32         NaN        NaN         NaN        NaN
# 18      497       26         NaN        NaN         NaN        NaN
# 19      498      102       22.69        0.0       48.49        0.0
# 20      499       34         NaN        NaN         NaN        NaN
# 21      500       24       38.00        0.0       68.00        0.0
# 22      501       38         NaN        NaN         NaN        NaN
# 23      503       39       25.00        0.0       78.00        0.0
# 24      505       43       19.03        0.0       54.65        0.0
# 25      506       42         NaN        NaN         NaN        NaN
# 26      507       46         NaN        NaN         NaN        NaN
# 27      508       44       40.78        0.0       61.04        0.0
# 28      519       56       26.00        0.0       54.00        2.0
# 29      522       45       29.60        0.0       39.20        0.0
# ..      ...      ...         ...        ...         ...        ...
# 77      634      161       19.30        1.0       55.81        1.0
# 78      639      163         NaN        NaN         NaN        NaN
# 79      644        5       30.67        0.0       42.07        0.0
# 80      649      166       20.85        0.0       50.99        1.0
# 81      651      170         NaN        NaN         NaN        NaN
# 82      654      173         NaN        NaN         NaN        NaN
# 83      655      178       25.37        0.0       92.96        1.0
# 84      656      172       29.44        0.0       58.82        0.0
# 85      658      185       40.82        0.0       89.32        0.0
# 86      659      164       24.80        0.0      102.14        2.0
# 87      660      169         NaN        NaN         NaN        NaN
# 88      662      171         NaN        NaN         NaN        NaN
# 89      663      184         NaN        NaN         NaN        NaN
# 90      665      180         NaN        NaN         NaN        NaN
# 91      666      182       31.19        0.0      128.49       18.0
# 92      667      186       37.83        0.0       92.08        0.0
# 93      668      181         NaN        NaN         NaN        NaN
# 94      669      174       26.75        0.0       64.50        0.0
# 95      670      190       14.72        0.0       41.30        0.0
# 96      671      176       25.82        0.0       74.00        1.0
# 97      674      197       35.29        0.0      116.34        1.0
# 98      675      191       41.23        0.0      119.99        0.0
# 99      676      199       25.21        0.0       58.85        2.0
# 100     677      195       35.12        0.0       58.03        0.0
# 101     678      202       50.45        0.0       58.44        0.0
# 102     682      203         NaN        NaN         NaN        NaN
# 103     684      204       48.46        0.0       41.65        0.0
# 104     687      206       29.46        0.0       73.68        2.0
# 105     695      208         NaN        NaN         NaN        NaN
# 106     713      209       34.20        0.0       72.26        1.0
#
#      post_time_a  post_err_a  post_time_b  post_err_b
# 0            NaN         NaN          NaN         NaN
# 1          23.00         0.0        44.00         0.0
# 2            NaN         NaN          NaN         NaN
# 3          21.61         0.0        48.51         0.0
# 4          26.00         0.0        61.00         0.0
# 5          27.00         0.0        63.00         0.0
# 6          39.51         1.0        72.12         0.0
# 7          23.93         0.0        45.08         4.0
# 8          36.00         0.0        63.00         0.0
# 9          40.30         1.0        64.93         0.0
# 10         26.03         0.0        46.67         0.0
# 11         24.00         0.0        43.00         0.0
# 12         47.00         0.0        79.00         0.0
# 13         34.63         0.0        58.39         0.0
# 14         25.56         0.0        43.03         0.0
# 15           NaN         NaN          NaN         NaN
# 16           NaN         NaN          NaN         NaN
# 17           NaN         NaN          NaN         NaN
# 18           NaN         NaN          NaN         NaN
# 19         21.22         0.0        70.60         0.0
# 20           NaN         NaN          NaN         NaN
# 21         33.08         0.0        63.14         0.0
# 22           NaN         NaN          NaN         NaN
# 23         27.00         1.0        64.00         0.0
# 24         26.00         3.0        63.00         0.0
# 25           NaN         NaN          NaN         NaN
# 26           NaN         NaN          NaN         NaN
# 27           NaN         NaN          NaN         NaN
# 28           NaN         NaN          NaN         NaN
# 29         18.67         0.0        41.71         0.0
# ..           ...         ...          ...         ...
# 77         21.98         0.0        40.46         0.0
# 78           NaN         NaN          NaN         NaN
# 79         24.58         0.0        37.26         0.0
# 80         20.90         0.0        41.49         1.0
# 81           NaN         NaN          NaN         NaN
# 82           NaN         NaN          NaN         NaN
# 83         25.93         0.0        77.08         1.0
# 84           NaN         NaN          NaN         NaN
# 85           NaN         NaN          NaN         NaN
# 86         19.87         0.0        66.38         1.0
# 87           NaN         NaN          NaN         NaN
# 88           NaN         NaN          NaN         NaN
# 89           NaN         NaN          NaN         NaN
# 90           NaN         NaN          NaN         NaN
# 91         33.21         0.0        59.27         0.0
# 92          3.25         0.0        90.30         0.0
# 93           NaN         NaN          NaN         NaN
# 94         26.74         0.0        84.37         0.0
# 95         15.08         0.0        31.65         0.0
# 96         22.82         0.0        69.89         0.0
# 97         29.24         2.0        62.73         2.0
# 98         38.42         3.0        74.88         0.0
# 99         22.32         0.0        35.71         0.0
# 100        21.00         0.0        46.07         1.0
# 101          NaN         NaN          NaN         NaN
# 102          NaN         NaN          NaN         NaN
# 103        21.17         0.0        38.75         0.0
# 104        24.38         0.0        81.69         0.0
# 105          NaN         NaN          NaN         NaN
# 106        34.32         0.0        74.59         1.0
#
# [107 rows x 10 columns]

# %% [markdown]
# ## Calculating Time Cost
# Finally, we need to calculate time cost for pre and post

# %%
trails_fmt['pre_timecost'] = trails_fmt['pre_time_b'] - trails_fmt['pre_time_a']
trails_fmt['post_timecost'] = trails_fmt['post_time_b'] - trails_fmt['post_time_a']

# %%
# Finished! (just sorting by pacr_id)
trails_fmt.sort_values(by=['pacr_id'], inplace=True)

# %%
# eliminating subjects who didn't have a pre_timecost
trails_fmt = trails_fmt[np.isfinite(trails_fmt['pre_timecost'])]

# %%
# mistype in REDCAP, changing 3.25 to 30.25 (what's intended)
trails_fmt['post_time_a'][92] = 30.25
# Out:
# /home/jdkent/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# write it to file.
trails_fmt.to_csv('./trails_fmt.tsv', sep='\t')
